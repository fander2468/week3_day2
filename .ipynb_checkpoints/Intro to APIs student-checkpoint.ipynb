# %% [markdown]
# # Working with APIs

# %% [markdown]
# API stands for Application programming interface<br>
# APIs are a way for applications to talk to eachother<br>
# In python we use the requests package to handle the connection<br>
# <small><strong>Note: It is requests with an s not request(this is a different package)</strong></small><br>
# Most API's communicate with data in the form of JSON<br>
# JSON stands for JavaScript Object Notation

# %%
#import the packages we need:
import requests, json

# %% [markdown]
# We will be connecting to the Ergast F1 Racer API today:
# http://ergast.com/mrd/
#
# to view JSON data nicely in the Chrome browser install the extension JSONview

# %%
help(requests)
# Out:
# Help on package requests:
#
# NAME
#     requests
#
# DESCRIPTION
#     Requests HTTP Library
#     ~~~~~~~~~~~~~~~~~~~~~
#
#     Requests is an HTTP library, written in Python, for human beings.
#     Basic GET usage:
#
#        >>> import requests
#        >>> r = requests.get('https://www.python.org')
#        >>> r.status_code
#        200
#        >>> b'Python is a programming language' in r.content
#        True
#
#     ... or POST:
#
#        >>> payload = dict(key1='value1', key2='value2')
#        >>> r = requests.post('https://httpbin.org/post', data=payload)
#        >>> print(r.text)
#        {
#          ...
#          "form": {
#            "key1": "value1",
#            "key2": "value2"
#          },
#          ...
#        }
#
#     The other HTTP methods are supported - see `requests.api`. Full documentation
#     is at <https://requests.readthedocs.io>.
#
#     :copyright: (c) 2017 by Kenneth Reitz.
#     :license: Apache 2.0, see LICENSE for more details.
#
# ...

# %%
url = "https://ergast.com/api/f1/2008/5/driverStandings.json"

# %%
response = requests.get(url)
response # if 200 then if was sucessful
# Out:
# <Response [200]>

# %%
#response object
help(response)
# Out:
# Help on Response in module requests.models object:
#
# class Response(builtins.object)
#  |  The :class:`Response <Response>` object, which contains a
#  |  server's response to an HTTP request.
#  |
#  |  Methods defined here:
#  |
#  |  __bool__(self)
#  |      Returns True if :attr:`status_code` is less than 400.
#  |
#  |      This attribute checks if the status code of the response is between
#  |      400 and 600 to see if there was a client error or a server error. If
#  |      the status code, is between 200 and 400, this will return True. This
#  |      is **not** a check to see if the response code is ``200 OK``.
#  |
#  |  __enter__(self)
#  |
#  |  __exit__(self, *args)
#  |
#  |  __getstate__(self)
#  |
#  |  __init__(self)
#  |      Initialize self.  See help(type(self)) for accurate signature.
#  |
#  |  __iter__(self)
#  |      Allows you to use a response as an iterator.
#  |
#  |  __nonzero__(self)
#  |      Returns True if :attr:`status_code` is less than 400.
# ...

# %%
#check and make sure we got a successful response from the API
response.ok
# Out:
# True

# %%
#view the response as a JSON
response.json()
# Out:
# {'MRData': {'xmlns': 'http://ergast.com/mrd/1.4',
#   'series': 'f1',
#   'url': 'http://ergast.com/api/f1/2008/5/driverstandings.json',
#   'limit': '30',
#   'offset': '0',
#   'total': '22',
#   'StandingsTable': {'season': '2008',
#    'round': '5',
#    'StandingsLists': [{'season': '2008',
#      'round': '5',
#      'DriverStandings': [{'position': '1',
#        'positionText': '1',
#        'points': '35',
#        'wins': '2',
#        'Driver': {'driverId': 'raikkonen',
#         'permanentNumber': '7',
#         'code': 'RAI',
#         'url': 'http://en.wikipedia.org/wiki/Kimi_R%C3%A4ikk%C3%B6nen',
#         'givenName': 'Kimi',
#         'familyName': 'Räikkönen',
#         'dateOfBirth': '1979-10-17',
#         'nationality': 'Finnish'},
#        'Constructors': [{'constructorId': 'ferrari',
#          'url': 'http://en.wikipedia.org/wiki/Scuderia_Ferrari',
#          'name': 'Ferrari',
#          'nationality': 'Italian'}]},
#       {'position': '2',
# ...

# %%
type(response.json())
# Out:
# dict

# %%
# We only want the Driver Standings
data = response.json()["MRData"]["StandingsTable"]["StandingsLists"][0]["DriverStandings"]
data
# Out:
# [{'position': '1',
#   'positionText': '1',
#   'points': '35',
#   'wins': '2',
#   'Driver': {'driverId': 'raikkonen',
#    'permanentNumber': '7',
#    'code': 'RAI',
#    'url': 'http://en.wikipedia.org/wiki/Kimi_R%C3%A4ikk%C3%B6nen',
#    'givenName': 'Kimi',
#    'familyName': 'Räikkönen',
#    'dateOfBirth': '1979-10-17',
#    'nationality': 'Finnish'},
#   'Constructors': [{'constructorId': 'ferrari',
#     'url': 'http://en.wikipedia.org/wiki/Scuderia_Ferrari',
#     'name': 'Ferrari',
#     'nationality': 'Italian'}]},
#  {'position': '2',
#   'positionText': '2',
#   'points': '28',
#   'wins': '2',
#   'Driver': {'driverId': 'massa',
#    'permanentNumber': '19',
#    'code': 'MAS',
#    'url': 'http://en.wikipedia.org/wiki/Felipe_Massa',
#    'givenName': 'Felipe',
#    'familyName': 'Massa',
#    'dateOfBirth': '1981-04-25',
#    'nationality': 'Brazilian'},
#   'Constructors': [{'constructorId': 'ferrari',
#     'url': 'http://en.wikipedia.org/wiki/Scuderia_Ferrari',
# ...

# %%
def get_racer_info(data):
    new_data = []
    for racer in data:
        racer_dict = {}
        racer_name = f"{racer['Driver']['givenName']}{racer['Driver']['familyName']}"
        racer_dict[racer_name] = {
            'first_name': racer['Driver']['givenName'],
            'last_name' : racer['Driver']['familyName'],
            'postion' : racer['position'],
            'wins': racer['wins'],
            'DOB': racer['Driver']['dateOfBirth'],
            'nationality': racer['Driver']['nationality'],
            'constructor': racer['Constructors'][0]['name']
                           
        }
        
        new_data.append(racer_dict)
    return new_data

get_racer_info(data)
# Out:
# [{'KimiRäikkönen': {'first_name': 'Kimi',
#    'last_name': 'Räikkönen',
#    'postion': '1',
#    'wins': '2',
#    'DOB': '1979-10-17',
#    'nationality': 'Finnish',
#    'constructor': 'Ferrari'}},
#  {'FelipeMassa': {'first_name': 'Felipe',
#    'last_name': 'Massa',
#    'postion': '2',
#    'wins': '2',
#    'DOB': '1981-04-25',
#    'nationality': 'Brazilian',
#    'constructor': 'Ferrari'}},
#  {'LewisHamilton': {'first_name': 'Lewis',
#    'last_name': 'Hamilton',
#    'postion': '3',
#    'wins': '1',
#    'DOB': '1985-01-07',
#    'nationality': 'British',
#    'constructor': 'McLaren'}},
#  {'RobertKubica': {'first_name': 'Robert',
#    'last_name': 'Kubica',
#    'postion': '4',
#    'wins': '0',
#    'DOB': '1984-12-07',
#    'nationality': 'Polish',
#    'constructor': 'BMW Sauber'}},
#  {'NickHeidfeld': {'first_name': 'Nick',
#    'last_name': 'Heidfeld',
#    'postion': '5',
#    'wins': '0',
#    'DOB': '1977-05-10',
#    'nationality': 'German',
# ...

# %%
def get_driver_info_by_year_and_round(year, r):
    url = f"https://ergast.com/api/f1/{year}/{r}/driverStandings.json"
    response = requests.get(url)
    if not response.ok:
        return "We had an error loading our data likely the year or round is not in the database"
    data = response.json()["MRData"]["StandingsTable"]["StandingsLists"][0]["DriverStandings"]
    return get_racer_info(data)

get_driver_info_by_year_and_round(2018, 1)
# Out:
# [{'SebastianVettel': {'first_name': 'Sebastian',
#    'last_name': 'Vettel',
#    'postion': '1',
#    'wins': '1',
#    'DOB': '1987-07-03',
#    'nationality': 'German',
#    'constructor': 'Ferrari'}},
#  {'LewisHamilton': {'first_name': 'Lewis',
#    'last_name': 'Hamilton',
#    'postion': '2',
#    'wins': '0',
#    'DOB': '1985-01-07',
#    'nationality': 'British',
#    'constructor': 'Mercedes'}},
#  {'KimiRäikkönen': {'first_name': 'Kimi',
#    'last_name': 'Räikkönen',
#    'postion': '3',
#    'wins': '0',
#    'DOB': '1979-10-17',
#    'nationality': 'Finnish',
#    'constructor': 'Ferrari'}},
#  {'DanielRicciardo': {'first_name': 'Daniel',
#    'last_name': 'Ricciardo',
#    'postion': '4',
#    'wins': '0',
#    'DOB': '1989-07-01',
#    'nationality': 'Australian',
#    'constructor': 'Red Bull'}},
#  {'FernandoAlonso': {'first_name': 'Fernando',
#    'last_name': 'Alonso',
#    'postion': '5',
#    'wins': '0',
#    'DOB': '1981-07-29',
# ...

# %% [markdown]
# # <strong>Homework</strong>
# check out this Pokemon API https://pokeapi.co/
# Use the requests package to connect to this API and get and store data for 5 different pokemon.
# Get the pokemons: name, atleast one ability's name, base_experience, and the URL for its sprite (an image that shows up on screen) for the 'front_shiny'

# %%
import requests, json

# store all urls in a list
# pokemon_urls = ['https://pokeapi.co/api/v2/pokemon/pikachu','https://pokeapi.co/api/v2/pokemon/squirtle',
#                 'https://pokeapi.co/api/v2/pokemon/bulbasaur','https://pokeapi.co/api/v2/pokemon/charmander',
#                 'https://pokeapi.co/api/v2/pokemon/charizard']
# all_url_data = []
# for link in pokemon_urls:
#     pull_data = requests.get(link).json()
#     all_url_data.append(pull_data)
# print(all_url_data)

# store each url in a seperate variable
url_1 = "https://pokeapi.co/api/v2/pokemon/pikachu"
url_2 = "https://pokeapi.co/api/v2/pokemon/squirtle"
url_3 = "https://pokeapi.co/api/v2/pokemon/bulbasaur"
url_4 = "https://pokeapi.co/api/v2/pokemon/charmander"
url_5 = "https://pokeapi.co/api/v2/pokemon/charizard"

# check each file 
response1 = requests.get(url_1)
print(f"The first file repsonse is: {response1.ok}")

response2 = requests.get(url_2)
print(f"The second file repsonse is: {response2.ok}")

response3 = requests.get(url_3)
print(f"The third file repsonse is: {response3.ok}")

response4 = requests.get(url_4)
print(f"The fourth file repsonse is: {response4.ok}")

response5 = requests.get(url_5)
print(f"The fifth file repsonse is: {response5.ok}\n\n")



# We only want the name, atleast one ability's name, base_experience, and the URL for its sprite 
# (an image that shows up on screen) for the 'front_shiny'

class PokemonCharaters():
    
    def __init__(self, file):
        self.file = file
        

    def character_parsed(self):
        list_of_chars = []
        for char in file:
            char_dict = {}
            char_name = f"{char['form']['name']}"
            char_dict[char_name] = {
                'ability':char['abilities']['ability']['name'],
                'base_experience':char['base_experience'],
                'sprite URL':char['sprites']['front_shiny']
            }
            list_of_chars.append(char_dict)
        return list_of_chars
    

print("===============1st Pokemon Charater Info============\n")
pokemon_character = PokemonCharaters(response1)        
pokemon_character.character_parsed()

print("\n===============2nd Pokemon Charater Info============\n")
pokemon_character = PokemonCharaters(response2)        
pokemon_character.character_parsed()

print("\n===============3rd Pokemon Charater Info============\n")
pokemon_character = PokemonCharaters(response3)        
pokemon_character.character_parsed()

print("\n===============4th Pokemon Charater Info============\n")
pokemon_character = PokemonCharaters(response4)        
pokemon_character.character_parsed()

print("\n===============5th Pokemon Charater Info============\n")
pokemon_character = PokemonCharaters(response5)        
pokemon_character.character_parsed()
# Out:
# The first file repsonse is: True
# The second file repsonse is: True
# The third file repsonse is: True
# YThe fourth file repsonse is: True
# The fifth file repsonse is: True
#
#
# ===============1st Pokemon Charater Info============
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-75-2a14da085c02> in <module>
#      61 print("===============1st Pokemon Charater Info============")
#      62 pokemon_character = PokemonCharaters(response1)
# ---> 63 pokemon_character.character_parsed()
#      64
#      65 print("===============2nd Pokemon Charater Info============")
#
# <ipython-input-75-2a14da085c02> in character_parsed(self)
#      49         for char in file:
#      50             char_dict = {}
# ---> 51             char_name = f"{char['form']['name']}"
#      52             char_dict[char_name] = {
# ...
